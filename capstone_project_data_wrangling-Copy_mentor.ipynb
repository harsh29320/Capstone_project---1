# %%
import pandas as pd

# %%
# url link to the csv file for importing college scorecard data
url = 'https://ed-public-download.app.cloud.gov/downloads/Most-Recent-Cohorts-All-Data-Elements.csv'

# %%
# url link to the csv file for importing earnings data
url1 = 'https://ed-public-download.app.cloud.gov/downloads/Most-Recent-Cohorts-Treasury-Elements.csv'

# %%
# Several values in the columns are represented as PrivacySuppressed: replacing them with NULL
df = pd.read_csv(url, na_values=['PrivacySuppressed'])
# Out:
# /Users/julie/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (6,9,1729,1743) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
### did a curl -O on the URL to download locally, your was is fine too.

# %%
df = pd.read_csv('Most-Recent-Cohorts-All-Data-Elements.csv',na_values=['PrivacySuppressed'])
# Out:
# /Users/julie/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (6,9,1729,1743) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
### I was getting a bunch of what looked like unicode characters in the first column name, so changed it to just be
### UNITID.  For whatever reason, you may not have to have done this.

# %%
df.rename(columns={df.columns[0]:'UNITID'},inplace=True)

# %%
#UNITID can be used as he index since it has a unique value for each school
#We developed a separate table using UNITID, name, city and state since these can only be used to identify school
schools = df[['UNITID', 'INSTNM', 'CITY', 'STABBR']]

# %%
schools.head()
# Out:
#    UNITID                               INSTNM        CITY STABBR
# 0  100654             Alabama A & M University      Normal     AL
# 1  100663  University of Alabama at Birmingham  Birmingham     AL
# 2  100690                   Amridge University  Montgomery     AL
# 3  100706  University of Alabama in Huntsville  Huntsville     AL
# 4  100724             Alabama State University  Montgomery     AL

# %%
#Deleting the columns that cant be used for model development: Zip, lat, long, opeid, opeid6, accreditor, school_url, price-calculator_url, repayment_date.median
#separation_date.median, alias, accreditor_code, title_iv.approval_date
other_columns = ['INSTNM', 'CITY','STABBR','OPEID', 'OPEID6', 'ZIP','ACCREDAGENCY','LATITUDE', 'LONGITUDE', 'INSTURL','NPCURL','REPAY_DT_MDN','SEPAR_DT_MDN','ACCREDCODE','T4APPROVALDATE']

# %%
df.drop(other_columns, axis = 1, inplace =True)

# %%
df.shape
# Out:
# (7593, 1790)

# %%
df.head()
# Out:
#    UNITID  SCH_DEG  HCM2  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL  ST_FIPS  \
# 0  100654      3.0     0     1          1        3        4        1        1
# 1  100663      3.0     0     1          1        3        4        1        1
# 2  100690      3.0     0     1          1        3        4        2        1
# 3  100706      3.0     0     1          1        3        4        1        1
# 4  100724      3.0     0     1          1        3        4        1        1
#
#    REGION       ...        OMENRYP8_FTNFT  OMENRAP8_FTNFT  OMENRUP8_FTNFT  \
# 0       5       ...                0.0000          0.1727          0.3909
# 1       5       ...                0.0102          0.2187          0.1385
# 2       5       ...                0.0125          0.4375          0.0000
# 3       5       ...                0.0124          0.3209          0.1242
# 4       5       ...                0.0000          0.3672          0.1977
#
# ...

# %%
# getting earnings data from the csv file Most-Recent-Cohorts-Treasury-Elements.csv
df_earnings = pd.read_csv(url1)

# %%
df_earnings.rename(columns={df_earnings.columns[0]:'UNITID'},inplace=True)

# %%
df_earnings.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM  COUNT_ED  \
# 0  100654   100200    1002             Alabama A & M University       NaN
# 1  100663   105200    1052  University of Alabama at Birmingham       NaN
# 2  100690  2503400   25034                   Amridge University       NaN
# 3  100706   105500    1055  University of Alabama in Huntsville       NaN
# 4  100724   100500    1005             Alabama State University       NaN
#
#             AGEGE24         PCT_WHITE         PCT_BLACK         PCT_ASIAN  \
# 0  0.07999999821186  46.8400001525878  47.9799995422363  1.48000001907348
# 1  0.25999999046325  69.0199966430664  27.7600002288818  1.10000002384185
# 2  0.82999998331069  70.8799972534179  22.5300006866455  1.28999996185302
# 3  0.28999999165534  76.3799972534179  18.9799995422363  1.41999995708465
# 4  0.10999999940395  42.6899986267089  52.3199996948242  1.40999996662139
#
# ...

# %%
# separating UNITID and MEDIAN_HH_INC, since MEDIAN_HH_INC will be predicted using other variables and UNITID will be used as index
# also separating OPEID and OPEID 6 since they have been already dropped from the main table
df_earnings.drop(['UNITID','OPEID','OPEID6','INSTNM','MEDIAN_HH_INC'], axis=1, inplace=True)

# %%
#The main file consists of all the fields so removing earnings columns from the main data except MEDIAN_HH_INC
df.drop(df_earnings.columns, axis=1, inplace = True)

# %%
df.shape
# Out:
# (7593, 1706)

# %%
# checking head of the data
df.head()
# Out:
#    UNITID  SCH_DEG  HCM2  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL  ST_FIPS  \
# 0  100654      3.0     0     1          1        3        4        1        1
# 1  100663      3.0     0     1          1        3        4        1        1
# 2  100690      3.0     0     1          1        3        4        2        1
# 3  100706      3.0     0     1          1        3        4        1        1
# 4  100724      3.0     0     1          1        3        4        1        1
#
#    REGION       ...        OMENRYP8_FTNFT  OMENRAP8_FTNFT  OMENRUP8_FTNFT  \
# 0       5       ...                0.0000          0.1727          0.3909
# 1       5       ...                0.0102          0.2187          0.1385
# 2       5       ...                0.0125          0.4375          0.0000
# 3       5       ...                0.0124          0.3209          0.1242
# 4       5       ...                0.0000          0.3672          0.1977
#
# ...

# %%
# visually inspecting the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7593 entries, 0 to 7592
# Columns: 1706 entries, UNITID to OMENRUP8_PTNFT
# dtypes: float64(1694), int64(11), object(1)
# memory usage: 98.8+ MB

# %%
df.describe()
# Out:
# /Users/julie/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:4274: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#              UNITID     SCH_DEG         HCM2         MAIN    NUMBRANCH  \
# count  7.593000e+03  7286.00000  7593.000000  7593.000000  7593.000000
# mean   1.765726e+06     1.89720     0.009219     0.738312     7.185566
# std    6.771661e+06     0.87879     0.095578     0.439583    21.184166
# min    1.006540e+05     1.00000     0.000000     0.000000     1.000000
# 25%    1.752630e+05         NaN     0.000000     0.000000     1.000000
# 50%    2.318730e+05         NaN     0.000000     1.000000     1.000000
# 75%    4.496120e+05         NaN     0.000000     1.000000     3.000000
# max    4.862110e+07     3.00000     1.000000     1.000000   135.000000
#
#            PREDDEG      HIGHDEG      CONTROL      ST_FIPS       REGION  \
# count  7593.000000  7593.000000  7593.000000  7593.000000  7593.000000
# ...

# %%
df.set_index('UNITID', inplace=True)

# %%
df.head()
# Out:
#         SCH_DEG  HCM2  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL  ST_FIPS  \
# UNITID
# 100654      3.0     0     1          1        3        4        1        1
# 100663      3.0     0     1          1        3        4        1        1
# 100690      3.0     0     1          1        3        4        2        1
# 100706      3.0     0     1          1        3        4        1        1
# 100724      3.0     0     1          1        3        4        1        1
#
#         REGION  LOCALE       ...        OMENRYP8_FTNFT  OMENRAP8_FTNFT  \
# UNITID                       ...
# 100654       5    12.0       ...                0.0000          0.1727
# 100663       5    12.0       ...                0.0102          0.2187
# 100690       5    12.0       ...                0.0125          0.4375
# 100706       5    12.0       ...                0.0124          0.3209
# 100724       5    12.0       ...                0.0000          0.3672
#
# ...

# %%
#checking for columns with less than 40 percent of null data
columns = df.isnull().sum()/df.shape[0]*100 < 40

# %%
df1 = df.loc[:,columns]

# %%
df1.head()
# Out:
#         SCH_DEG  HCM2  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL  ST_FIPS  \
# UNITID
# 100654      3.0     0     1          1        3        4        1        1
# 100663      3.0     0     1          1        3        4        1        1
# 100690      3.0     0     1          1        3        4        2        1
# 100706      3.0     0     1          1        3        4        1        1
# 100724      3.0     0     1          1        3        4        1        1
#
#         REGION  LOCALE    ...     MALE_RPY_3YR_RT_SUPP  \
# UNITID                    ...
# 100654       5    12.0    ...                 0.245985
# 100663       5    12.0    ...                 0.541336
# 100690       5    12.0    ...                 0.306250
# 100706       5    12.0    ...                 0.594189
# 100724       5    12.0    ...                 0.175749
#
#         FIRSTGEN_RPY_3YR_RT_SUPP  NOTFIRSTGEN_RPY_3YR_RT_SUPP  ICLEVEL  \
# UNITID
# ...

# %%
import numpy as np

# %%
#checking for nan values
np.where(np.isnan(df1))
# Out:
# (array([   2,    2,    2, ..., 7592, 7592, 7592]),
#  array([289, 291, 292, ..., 594, 595, 596]))

# %%
#filling the null data with mean
df1.fillna(df1.mean(), inplace=True).head()
# Out:
# /Users/julie/anaconda/lib/python3.5/site-packages/pandas/core/generic.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#         SCH_DEG  HCM2  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL  ST_FIPS  \
# UNITID
# 100654      3.0     0     1          1        3        4        1        1
# 100663      3.0     0     1          1        3        4        1        1
# 100690      3.0     0     1          1        3        4        2        1
# 100706      3.0     0     1          1        3        4        1        1
# 100724      3.0     0     1          1        3        4        1        1
#
#         REGION  LOCALE    ...     MALE_RPY_3YR_RT_SUPP  \
# UNITID                    ...
# 100654       5    12.0    ...                 0.245985
# ...

# %%
from sklearn.feature_selection import SelectFromModel

# %%
y = df1['MEDIAN_HH_INC']

# %%
X = df1.drop('MEDIAN_HH_INC', axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor()

# %%
sfm = SelectFromModel(clf, threshold=0.005)
sfm.fit(X, y)
n_features = sfm.transform(X).shape[1]
features = sfm.transform(X)

# %%
n_features
# Out:
# 20

# %%
type(features)
# Out:
# numpy.ndarray

# %%
sfm.get_support(indices=True)
# Out:
# array([  7,   8,   9, 255, 256, 264, 265, 268, 271, 272, 273, 275, 277,
#        279, 359, 371, 389, 396, 397, 570])

# %%
type(X.columns)
# Out:
# pandas.indexes.base.Index

# %%
### dataframe with just features that have a feature importance > .005 in the random forrest

# %%
df1.iloc[:,sfm.get_support(indices=True)]
# Out:
#           ST_FIPS  REGION     LOCALE  UGDS_HISP  UGDS_ASIAN  UGDS_API  \
# UNITID
# 100654          1       5  12.000000   0.005800     0.00180  0.002500
# 100663          1       5  12.000000   0.031700     0.05950  0.041900
# 100690          1       5  12.000000   0.019500     0.00000  0.012900
# 100706          1       5  12.000000   0.041700     0.03810  0.029000
# 100724          1       5  12.000000   0.011600     0.00320  0.000000
# 100751          1       5  13.000000   0.039900     0.01130  0.011100
# 100760          1       5  32.000000   0.012300     0.00450  0.000000
# 100812          1       5  31.000000   0.018900     0.00620  0.000000
# 100830          1       5  12.000000   0.007000     0.02410  0.015600
# 100858          1       5  13.000000   0.032300     0.02500  0.018200
# 100937          1       5  12.000000   0.020800     0.05350  0.041100
# 101028          1       5  41.000000   0.045300     0.01090  0.000000
# ...

# %%
### your error was from the fact that you did not give select from model an estimator to work with.  It needs an estimator 
### to run your features through so that it can either look at feature importance or coeffecients.  You also have to make
### sure to use a model that fits the type of Y you have.  In this case you have continuous data so you need a
### model that is a regressor.  If you used a classifier, you would have gotten antoher error.
