# %%
import pandas as pd

# %%
# url link to the csv file for importing college scorecard data
url = 'https://ed-public-download.app.cloud.gov/downloads/Most-Recent-Cohorts-All-Data-Elements.csv'

# %%
# reading data into a dataframe 
data = pd.read_csv(url)
# Out:
# C:\Users\harshvardhan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (6,9,1608,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1688,1689,1690,1691,1692,1703,1704,1725,1726,1727,1728,1729,1743) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# checking head of the data
data.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP                                       ACCREDAGENCY  \
# 0     AL       35762  Southern Association of Colleges and Schools C...
# 1     AL  35294-0110  Southern Association of Colleges and Schools C...
# 2     AL  36117-3553  Southern Association of Colleges and Schools C...
# 3     AL       35899  Southern Association of Colleges and Schools C...
# 4     AL  36104-0271  Southern Association of Colleges and Schools C...
#
#                      INSTURL  \
# 0              www.aamu.edu/
# ...

# %%
# visually inspecting the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7593 entries, 0 to 7592
# Columns: 1805 entries, UNITID to OMENRUP8_PTNFT
# dtypes: float64(504), int64(13), object(1288)
# memory usage: 104.6+ MB

# %%
data.describe()
# Out:
#              UNITID         OPEID        OPEID6     SCH_DEG         HCM2  \
# count  7.593000e+03  7.593000e+03   7593.000000  7286.00000  7593.000000
# mean   1.765726e+06  1.910166e+06  16441.276307     1.89720     0.009219
# std    6.771661e+06  3.516382e+06  14088.868371     0.87879     0.095578
# min    1.006540e+05  1.002000e+05   1002.000000     1.00000     0.000000
# 25%    1.752630e+05  3.402000e+05   3395.000000     1.00000     0.000000
# 50%    2.318730e+05  1.054211e+06  10490.000000     2.00000     0.000000
# 75%    4.496120e+05  3.010617e+06  26092.000000     3.00000     0.000000
# max    4.862110e+07  8.209884e+07  42542.000000     3.00000     1.000000
#
#               MAIN    NUMBRANCH      PREDDEG      HIGHDEG      CONTROL  \
# count  7593.000000  7593.000000  7593.000000  7593.000000  7593.000000
# mean      0.738312     7.185566     1.810088     2.202292     2.192282
# std       0.439583    21.184166     1.031903     1.318152     0.835941
# ...

# %%
# Several values in the columns are represented as PrivacySuppressed: replacing them with NULL
data = data.replace('PrivacySuppressed', 'NULL')

# %%
#Calculating percentage of NULL data in each column and selecting those that have less than 5% NULL values
columns_2 = data.isnull().sum()/data.shape[0]*100 < 5

# %%
columns_2
# Out:
# UNITID                          True
# OPEID                           True
# OPEID6                          True
# INSTNM                          True
# CITY                            True
# STABBR                          True
# ZIP                             True
# ACCREDAGENCY                   False
# INSTURL                         True
# NPCURL                         False
# SCH_DEG                         True
# HCM2                            True
# MAIN                            True
# NUMBRANCH                       True
# PREDDEG                         True
# HIGHDEG                         True
# CONTROL                         True
# ST_FIPS                         True
# REGION                          True
# LOCALE                         False
# LATITUDE                       False
# LONGITUDE                      False
# CCBASIC                        False
# CCUGPROF                       False
# CCSIZSET                       False
# ...

# %%
data.loc[:,columns_2].shape
# Out:
# (7593, 99)
